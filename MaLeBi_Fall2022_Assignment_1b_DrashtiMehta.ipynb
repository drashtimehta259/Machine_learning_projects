# %% [markdown]
# # Assignment 1b
#
#
# ## Students
#
# Please enter your data in the placeholders below.
#
# - Your full name: [PLACEHOLDER]
# - Your UNC Charlotte's email: [PLACEHOLDER]
# - Today's date: [PLACEHOLDER]
#
# ## Instructions
#
# This is a Google Colab file. Read the text and execute the code in order. Each "question" subsection has an "answer." Enter your answers as indicated. Once you are done, download this Colab as an `ipynb` file. See instructions on how to upload your `.ipynb` file in CANVAS.
#
# You don't need to answer all the questions in this Colab. Instead, check for a message from the instructor indicating which questions you must respond to compensate for points you might have missed from assignment 1. If you have not received that message from the instructor, please wait 12 hours from when this assignment was posted before messaging the instructor. The message may still be on its way to you.

# %% [markdown]
# # Question 1b
#
# Let us learn about slopes and intercepts by plotting some linear functions in R. First, see the code sections beloow to learn how to plot functions.

# %% [markdown]
# ## The `curve()` function
# It is easy to plot lines and curves in R using the `curve()` function. Below, we are plotting four different equations using the `curve()` function. Read the code below to understand better how the `curve()` function works.

# %%
# Set up a 2 by 2 grip for plotting
par(mfrow=c(2,2))

# Curve for the equation x^3-3*x:
curve(x^3-3*x, -2, 2)

# Add curve for the equation x^2-2 on top of the previous plot:
curve(x^2-2, add = TRUE, col = "violet")

# New curve for the sin function: 
curve(sin, -pi, 3*pi)

# New curve for the cos function:
curve(cos, -pi, 3*pi)

# New curve for the log function:
curve(log(1+x), 1,100, log="x", sub=paste("log=","x"))
# Out:
# plot without title

# %% [markdown]
# This is how we would plot the curve for $Y = -5X + 10$.

# %%
# New curve for the log function:
curve(-5*x-10, -100, 100)
# Out:
# plot without title

# %% [markdown]
# ## Question 1b, part I
#
# In the code box below, use the `curve()` function to plot the lines corresponding the the following linear equations in a 3 by 3 grid using an interval from 0 to 10:
#
# 1. $Y = 5X-10$
# 2. $Y = 10X-5$
# 3. $Y = 5X+10$
# 4. $Y = 10X+5$
# 5. $Y = X$
# 6. $Y = X + \pi$
# 7. $Y = \pi \times X$
# 8. $Y = -\pi \times X$
# 9. $Y = 10$

# %%
# ENTER YOUR CODE HERE

# %% [markdown]
# ## Question 1b, part II
#
# The nine linear equations above have the format $Y = a + bX$. For each of the nine linear equations above, indicate what is the slope ($b$) and what is the intercept ($a$) by filling the placeholders below.

# %% [markdown]
# 1.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 2.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 3.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 4.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 5.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 6.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 7.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 8.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*
# 9.    $a =$ *PLACEHOLDER*, $b =$ *PLACEHOLDER*

# %% [markdown]
# # Question 2b
#
# - Your next answer will be a code in R.
# - The code is reading data from the `mtcars` dataset.
# - Your goal is to fix the code below, that tries to investigate whether we can create a linear model that correlates "Vehicle Weight" and "Vehicle Fuel Efficiency in Miles per Gallon."
# - You also want to show how useful that model could be in making predictions.
# - Once fixed, the code should automatically generates a training dataset with 80% of the data and a testing dataset with 20% of the data.
# - For each iteraction, the code should make sure that you only accept a new testing dataset if it is not identical to any other testing dataset from previous iterations.
# - The code should calculate and and store the RMSE of each iteration until you have tested 10 different test datasets extracted from the original `mtcars` dataset.
# - The code should create a plot with the residual standard error of each iteration. The plot should be shown to the user (make it appear after you execute the code).

# %% [markdown]
# ## Question 2b, part I
#
# Fix the code below. Half of the lines contain errors. Some of the errors may allow the code to run but will cause the analyses to be incorrect, therefore you must inspect each line and each equation carefully.
#
# Your final code should be formatted to improve readability. Also include comments explaining what each section of the code is doing, unless you think that the line is self-explanatory (very easy to interpret without comments).

# %%
percentageOfTrainingSet<-0,8
sizeOfTrainingSet=floor(percentageOfTrainingSet*nrow(mtcars))
rememberAllIndices<-list)
storeRMSEs<-vector("numeric",10L)
for (iteration in 1...10){
continue<-FALSE
while(identical(continue,FALSE){
indicesForTraining<-sample(nrow(mtcars),size=sizeOfTrainingSet)
indicesForTraining<-sort(indicesForTraining
if(list(indicesForTraining)%in%rememberAllIndices){continue<-FALSE}
else {{continue<-TRUE
rememberAllIndices<-c(rememberAllIndices,list(indicesForTraining))}}
test<-mtcars[-indicesForTraining]
test$output<-predict(model,new.data)
train<-mtcars[indicesForTraining,]
model<-lm(mpg~disp,data=test)
new.data<-data.frame(disp=test$disp)
rootMeanSquareError<-sqrt(sum(test$mpg-test$output) * 2/nrow(test))
storeRMSEs[iteration]<-rootMeanSquareError}
p<-plot(storeRMSEs,ylab="Iteration",xlab="RMSE")
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:27: unexpected ','
# 1: percentageOfTrainingSet<-0,
#                               ^
# Traceback:

# %% [markdown]
# ## Question 2b, Part II
#
# Copy the code from Answer 2b, Part I below. Modify it so that you retrieve the slope and intercept of the new linear function that is calculated at each of the 10 iterations. Make sure the new code is prining those values into the standard output.

# %%
## ENTER YOUR NEW CODE HERE AND MAKE SURE THAT IT IS COMMENTED AND FORMATTED SO THAT IT IS EASY TO READ.

# creating vectors
rememberAllIndices<-list() # added '(' before ')'
storeRMSEs<-vector("numeric",10L) 

# training set
percentageOfTrainingSet<-0.8 #training set is 80% (, replaced by . here)
sizeOfTrainingSet=floor(percentageOfTrainingSet*nrow(mtcars)) # size set to 80% and values provided

# iterations
for (iteration in 1:10) # for loop initiated (... replaced by :)
{ 
  continue<-FALSE
  while(identical(continue,FALSE)) # while loop, ) inserted after false bracket
    {
    indicesForTraining<-sample(nrow(mtcars),size=sizeOfTrainingSet)
    indicesForTraining<-sort(indicesForTraining) # closing bracket ) inserted
    if(list(indicesForTraining) %in% rememberAllIndices){continue<-FALSE}
    else {
      continue<-TRUE
    rememberAllIndices<-c(rememberAllIndices,list(indicesForTraining))
    }
  }
  # lines rearranged
  train<-mtcars[indicesForTraining,]
  test<-mtcars[-indicesForTraining,] # comma added
  model<-lm(mpg~disp,data=train) # train not test
  
  print(coef(model)) # slope and intercept values getting printed
  
  new.data<-data.frame(disp=test$disp)
  test$output<-predict(model,new.data)
  
  # RMSE values
  rootMeanSquareError<-sqrt(sum(test$mpg-test$output) ^ 2/nrow(test)) # * replaced by ^ before 2
  storeRMSEs[iteration]<-rootMeanSquareError }

  # plotting
p<-plot(storeRMSEs,ylab="RMSE",xlab="Iterations")
# Out:
# (Intercept)        disp
#  28.3002136  -0.0370838
# (Intercept)        disp
# 30.89044555 -0.04518828
# (Intercept)        disp
#  30.7989955  -0.0440862
# (Intercept)        disp
# 28.98978115 -0.03978338
# (Intercept)        disp
# 31.29996421 -0.04900085
# (Intercept)        disp
# 30.44881395 -0.04321468
# (Intercept)        disp
# 29.42324259 -0.04133111
# (Intercept)        disp
#  28.6118634  -0.0377388
# (Intercept)        disp
#  29.7133409  -0.0425902
# (Intercept)        disp
# 30.43196979 -0.04656031
# plot without title

# %% [markdown]
# # Question 3
#
# Whenever we fit a linear regression model in R, the model takes on the following form:
#
# $Y = β0 + β1X + … + βiX +ϵ$
#
# where $ϵ$ is an error term that is independent of $X$.
#
# No matter how well $X$ can be used to predict the values of $Y$, there will always be some random error in the model. One way to measure the dispersion of this random error is to use the **residual standard error** (RSE), which is a way to measure the standard deviation of the residuals $ϵ$.
#
# The residual standard error of a regression model is calculated as:
#
# Residual standard error $=$ (SS$_{residuals}$ / df$_{residuals}$)$^{1/2}$
#
# where:
#
# - SS$_{residuals}$: The residual sum of squares.
# - df$_{residuals}$: The residual degrees of freedom, calculated as $n – k – 1$ where $n =$ total observations and $k =$ total model parameters.
#
# There are three methods we can use to calculate the residual standard error of a regression model in R.
#
# One way to obtain the residual standard error is to simply fit a linear regression model and then use the `summary()` command to obtain the model results. Then, just look for "residual standard error" near the bottom of the output. Alternativelly, you can obtain the residual standard error (RSE) is to fit a linear regression model (the `model`) and then use the following formula to calculate RSE: `sqrt(deviance(model)/df.residual(model))`.

# %% [markdown]
# ## Question 3b, Part I
#
# What is the residual standart error (RSE) for the model calculated in the code below?

# %%
# Set a random seed:
set.seed(62108210)

# Load built-in mtcars dataset:
data(mtcars)

# Fit regression model:
model <- lm(mpg ~ disp + hp, data = mtcars)

# %% [markdown]
# ## Question 3b, Part II
#
# As mentioned before, the residual standard error (RSE) is a way to measure the standard deviation of the residuals in a regression model.
#
# Whenthe model is getting closer to fit the data, does the RSE increases or does it decreases? Why?

# %% [markdown]
# **TYPE THE ANSWER FOR QUESTION 3B, PART II IN HERE.**

# %% [markdown]
# # CHALLENGE: Question 4b
#
# Visit the website https://www.tylervigen.com/spurious-correlations. Select any example from their first page and show how you would calculate the linear correlation between those variables in R. Note that you will have to type the dataset yourself (its part of the training).
#
# Here is one example using the correlation between films Nicholas Cage appears in and the number of people drowned by falling into a pool. Just do the same with a different dataset. Note that I am simply collecting data from their images.

# %%
year <- c(1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009)
swimmingPoolDrowings <- c(
  109,
  102,
  102,
  98,
  85,
  95,
  96,
  98,
  123,
  94,
  102
)
nicholasCageFilms <- c(
  2,
  2,
  2,
  3,
  1,
  1,
  2,
  3,
  4,
  1,
  4
)
df <- data.frame(year, swimmingPoolDrowings, nicholasCageFilms)
colnames(df) <- c("year", "pools", "films")
plot(df$films, df$pools, xlab = "Nuber of films with Nicholas Cage", ylab = "Number of people drowned by falling into a pool", main = "Example of spurious correlation")
model <- lm(films ~ pools, data = df)
Pvalue <- summary(model)$coefficients[4]
Rsquared <- summary(model)$r.squared
cat(paste0("The p-value is ", Pvalue, " and the R-squared is ", Rsquared, ".\n"))
# Out:
# The p-value is 0.0284494894705637 and the R-squared is 0.443561792444576.
# Plot with title “Example of spurious correlation”

# %% [markdown]
# In the example above, the $R^2$ is note the same as the one reported in the Spurious Correlations website, but it is significative. Differences are probably due to the fact that the correlation is non-linear. We will talk more about that in class. For now, do not worry if you cannot retrieve the same correlation as the website.

# %% [markdown]
# ## Question 4b, Part I
#
# In the code box bellow, calculate te linear correlation for a different example using data from the website https://www.tylervigen.com/spurious-correlations. Make sure to plot the data in whatever manner you prefer and report the values of *p* and $R^2$.

# %%
# ENTER YOUR CODE HERE.

# %% [markdown]
# ## Question 4b, Part II
#
# What is the difference between correlation and causation? Define both terms using citations from the especialized literature. Keep your answer short (no more than one paragraph per definition).
#
# After you are done with that, write a final paragraph explaining what is the "*p* value crisis." Use all of the following terms (or similar variations of those terms) in your final paragraph:
# - *p* value
# - correlation
# - causation
# - significance
# - reproducible
# - support
# - evidence
# - falsifiability
#
# Make sure to highlight keywords in bold so that the instructor does not miss any of than during review.

# %% [markdown]
# ENTER YOUR PARAGRAPH WITH THE DEFINITION OF CORELATION HERE.
#
# ENTER YOUR PARAGRAPH WITH THE DEFINITION OF CAUSATION HERE.
#
# ENTER YOUR PARAGRAPH EXPLAINING THE P VALUE CRISIS HERE.
#
# ENTER YOUR REFERENCES HERE.
